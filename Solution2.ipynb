# %%
import keras
import random
import collections
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import mnist
from keras.datasets import mnist
from sklearn.model_selection import train_test_split
from collections import Counter

# %%
dataset = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
print("There are",len(dataset[0][0]),"images in training dataset")

print("There are",len(dataset[1][0]),"images in training dataset")
# Out:
# There are 60000 images in training dataset
# There are 10000 images in training dataset
# (28, 28)

# %%
display(collections.Counter(dataset[0][1]))
# Out:
# Counter({5: 5421,
#          0: 5923,
#          4: 5842,
#          1: 6742,
#          9: 5949,
#          2: 5958,
#          3: 6131,
#          6: 5918,
#          7: 6265,
#          8: 5851})

# %%
display(collections.Counter(dataset[1][1]))
# Out:
# Counter({7: 1028,
#          2: 1032,
#          1: 1135,
#          0: 980,
#          4: 982,
#          9: 1009,
#          5: 892,
#          6: 958,
#          3: 1010,
#          8: 974})

# %%
def display_random_images_with_labels(d, n=5):
    """
        accept dataset in tuple form, first index
        is np arrays (images) and second is labels
        and display n random images with labels
        from it
        Inputs:
            d (tuple): dataset images, dataset labels on same indexs
            n (int): number of samples to display (default: 10)
        Output:
            None
    """
    choices = list(range(len(d[0])))
    for i in range(n):
        index = random.choice(choices)
        choices.remove(index)
        print("index:",index)
        print("Lable:",d[1][index])
        plt.imshow(d[0][index], cmap='gray')
        plt.show()

# %%
display_random_images_with_labels(dataset[0])
# Out:
# index: 15021
# Lable: 8
# index: 48333
# Lable: 7
# index: 41607
# Lable: 1
# index: 5966
# Lable: 1
# index: 38784
# Lable: 2

# %%
X = np.random.rand(60000, 28, 28)
y = np.random.randint(0, 10, size=60000)

# %%
samples_per_class = 6000 // 10

# %%
X_reduced, _, y_reduced, _ = train_test_split(X, y, train_size=samples_per_class, stratify=y, random_state=42)
print("Reduced dataset class distribution:", Counter(y_reduced))
# Out:
# Reduced dataset class distribution: Counter({1: 61, 3: 61, 0: 61, 7: 60, 8: 60, 2: 60, 5: 60, 9: 59, 6: 59, 4: 59})

# %%
display(collections.Counter(y_reduced))
# Out:
# Counter({1: 61, 7: 60, 9: 59, 8: 60, 2: 60, 6: 59, 4: 59, 3: 61, 0: 61, 5: 60})
